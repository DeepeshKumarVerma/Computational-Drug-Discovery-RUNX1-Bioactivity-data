# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery Bioactivity Data**
#
# Deepesh Kumar Verma
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for RUNX1**

# %%
# Target search for RUNX1 (CHEMBL2093862)
target = new_client.target
target_query = target.search('RUNX1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
#
#                                            pref_name  score  \
# 0  Runt-related transcription factor 1/Core-bindi...    8.0
#
#    species_group_flag target_chembl_id  \
# 0               False    CHEMBL2093862
#
#                                    target_components  \
# 0  [{'accession': 'Q01196', 'component_descriptio...
#
#                    target_type  tax_id
# 0  PROTEIN-PROTEIN INTERACTION    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human RUNX1* (first entry)**

# %% [markdown]
# We will assign the first entry (which corresponds to the target protein, *Human RUNX1*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2093862'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human RUNX1* (CHEMBL2093862) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None           Active      5505465                  []
# 1        None           Active      5505466                  []
# 2        None           Active      5505467                  []
# 3        None           Active      5505468                  []
# 4        None           Active      5505469                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 1   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 2   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 3   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 4   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                                   target_pref_name  \
# 0    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 1    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 2    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 3    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 4    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
#
#   target_tax_id text_value  toid  type units    uo_units upper_value value
# 0          9606       None  None  IC50    uM  UO_0000065        None  2.22
# 1          9606       None  None  IC50    uM  UO_0000065        None  5.51
# 2          9606       None  None  IC50    uM  UO_0000065        None  36.3
# 3          9606       None  None  IC50    uM  UO_0000065        None  5.46
# 4          9606       None  None  IC50    uM  UO_0000065        None  33.6
#
# [5 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.standard_value
# Out:
# 0        2220.0
# 1        5510.0
# 2       36300.0
# 3        5460.0
# 4       33600.0
#          ...
# 190    100000.0
# 191      1865.2
# 192      713.43
# 193     13417.0
# 194     10337.0
# Name: standard_value, Length: 195, dtype: object

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('RUNX1_bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df.shape
# Out:
# (195, 46)

# %%
df1 = df[df.standard_value.notna()]
df1 = df1[df.canonical_smiles.notna()]
df1.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None           Active      5505465                  []
# 1        None           Active      5505466                  []
# 2        None           Active      5505467                  []
# 3        None           Active      5505468                  []
# 4        None           Active      5505469                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 1   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 2   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 3   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 4   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                                   target_pref_name  \
# 0    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 1    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 2    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 3    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 4    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
#
#   target_tax_id text_value  toid  type units    uo_units upper_value value
# 0          9606       None  None  IC50    uM  UO_0000065        None  2.22
# 1          9606       None  None  IC50    uM  UO_0000065        None  5.51
# 2          9606       None  None  IC50    uM  UO_0000065        None  36.3
# 3          9606       None  None  IC50    uM  UO_0000065        None  5.46
# 4          9606       None  None  IC50    uM  UO_0000065        None  33.6
#
# [5 rows x 46 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                0 non-null      object
#  1   activity_comment           195 non-null    object
#  2   activity_id                195 non-null    int64
#  3   activity_properties        195 non-null    object
#  4   assay_chembl_id            195 non-null    object
#  5   assay_description          195 non-null    object
#  6   assay_type                 195 non-null    object
#  7   assay_variant_accession    0 non-null      object
#  8   assay_variant_mutation     0 non-null      object
#  9   bao_endpoint               195 non-null    object
#  10  bao_format                 195 non-null    object
#  11  bao_label                  195 non-null    object
#  12  canonical_smiles           195 non-null    object
#  13  data_validity_comment      0 non-null      object
#  14  data_validity_description  0 non-null      object
#  15  document_chembl_id         195 non-null    object
#  16  document_journal           0 non-null      object
#  17  document_year              0 non-null      object
#  18  ligand_efficiency          125 non-null    object
#  19  molecule_chembl_id         195 non-null    object
#  20  molecule_pref_name         4 non-null      object
#  21  parent_molecule_chembl_id  195 non-null    object
#  22  pchembl_value              125 non-null    object
#  23  potential_duplicate        195 non-null    int64
#  24  qudt_units                 195 non-null    object
#  25  record_id                  195 non-null    int64
#  26  relation                   195 non-null    object
#  27  src_id                     195 non-null    int64
#  28  standard_flag              195 non-null    int64
#  29  standard_relation          195 non-null    object
#  30  standard_text_value        0 non-null      object
#  31  standard_type              195 non-null    object
#  32  standard_units             195 non-null    object
#  33  standard_upper_value       0 non-null      object
#  34  standard_value             195 non-null    object
#  35  target_chembl_id           195 non-null    object
#  36  target_organism            195 non-null    object
#  37  target_pref_name           195 non-null    object
#  38  target_tax_id              195 non-null    object
#  39  text_value                 0 non-null      object
#  40  toid                       0 non-null      object
#  41  type                       195 non-null    object
#  42  units                      195 non-null    object
#  43  uo_units                   195 non-null    object
#  44  upper_value                0 non-null      object
#  45  value                      195 non-null    object
# dtypes: int64(5), object(41)
# memory usage: 71.6+ KB

# %%
len(df1.canonical_smiles.unique())
# Out:
# 94

# %%
df1_nr = df1.drop_duplicates(['canonical_smiles'])
df1_nr.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None           Active      5505465                  []
# 1        None           Active      5505466                  []
# 2        None           Active      5505467                  []
# 3        None           Active      5505468                  []
# 4        None           Active      5505469                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 1   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 2   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 3   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
# 4   CHEMBL1613917  PUBCHEM_BIOASSAY: uHTS identification of compo...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                                   target_pref_name  \
# 0    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 1    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 2    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 3    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
# 4    Homo sapiens  Runt-related transcription factor 1/Core-bindi...
#
#   target_tax_id text_value  toid  type units    uo_units upper_value value
# 0          9606       None  None  IC50    uM  UO_0000065        None  2.22
# 1          9606       None  None  IC50    uM  UO_0000065        None  5.51
# 2          9606       None  None  IC50    uM  UO_0000065        None  36.3
# 3          9606       None  None  IC50    uM  UO_0000065        None  5.46
# 4          9606       None  None  IC50    uM  UO_0000065        None  33.6
#
# [5 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df2 = df1_nr[selection]
df2.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL1339329     CCCOc1ccc(C2C(C(=O)OC)=CN(CCOC)C=C2C(=O)OC)cc1
# 1      CHEMBL1378709  CCCc1cc2c(OC(=O)CC)c(-c3ccc(C(=O)OCC)o3)c(=O)o...
# 2      CHEMBL1464508  Cc1cc2c(c(=O)n1CCc1ccccc1)C(c1ccco1)C(C#N)=C(N)O2
# 3      CHEMBL1323994      O=S(=O)(Nc1ccc(-c2nc3cccnc3s2)cc1)c1ccc(Cl)s1
# 4      CHEMBL1338756  COc1cccc(-c2nc(-c3ccc4c(c3)-c3ccccc3S4(=O)=O)c...
#
#   standard_value
# 0         2220.0
# 1         5510.0
# 2        36300.0
# 3         5460.0
# 4        33600.0

# %% [markdown]
# Saves dataframe to CSV file

# %%
df2.to_csv('RUNX1_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ## Labeling compounds as either being active, inactive or intermediate
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000nM will be considered to be active while those greater than 10000nM will be considered to be inactive. As for those values in between 1000- 10000nM will be referred to as intermediate.

# %%
bioactivity_threshold = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df3 = pd.concat([df2, bioactivity_class], axis=1)
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL1339329     CCCOc1ccc(C2C(C(=O)OC)=CN(CCOC)C=C2C(=O)OC)cc1
# 1      CHEMBL1378709  CCCc1cc2c(OC(=O)CC)c(-c3ccc(C(=O)OCC)o3)c(=O)o...
# 2      CHEMBL1464508  Cc1cc2c(c(=O)n1CCc1ccccc1)C(c1ccco1)C(C#N)=C(N)O2
# 3      CHEMBL1323994      O=S(=O)(Nc1ccc(-c2nc3cccnc3s2)cc1)c1ccc(Cl)s1
# 4      CHEMBL1338756  COc1cccc(-c2nc(-c3ccc4c(c3)-c3ccccc3S4(=O)=O)c...
#
#   standard_value         class
# 0         2220.0  intermediate
# 1         5510.0  intermediate
# 2        36300.0      inactive
# 3         5460.0  intermediate
# 4        33600.0      inactive

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('RUNX1_bioactivity_data_curated.csv', index=False)

# %%
! zip RUNX1.zip *.csv
# Out:
#   adding: RUNX1_bioactivity_data.csv (deflated 92%)
#   adding: RUNX1_bioactivity_data_curated.csv (deflated 69%)
#   adding: RUNX1_bioactivity_data_preprocessed.csv (deflated 66%)

# %%
! ls -l
# Out:
# total 196
# -rw-r--r-- 1 root root 155828 Nov 16 11:45 RUNX1_bioactivity_data.csv
# -rw-r--r-- 1 root root   7594 Nov 16 11:45 RUNX1_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root   6590 Nov 16 11:45 RUNX1_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  17420 Nov 16 11:45 RUNX1.zip
# drwxr-xr-x 1 root root   4096 Nov 14 14:23 sample_data

# %% [markdown]
# ## Brief summary of what we did in part 1
# 1. Downloaded the dataset of biological activity from ChEMBL dataset
# 2. Dataset contains the molecule_names and corresponding Smile_notation which is the
#  information about the chemical structure of the compound. The data also contains the standard value.
# 3. Applied binning into Bioactivity class into active, intermediate and inactive.

# %% [markdown]
# ---
